# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# source de la carte:
# https://www.bfs.admin.ch/bfs/fr/home/statistiques/statistique-regions/fonds-cartes/geometries-base.assetdetail.33807959.html

# %%
regions = gpd.read_file("../2025_GEOM_TK/03_ANAL/Gesamtfläche_gf/K4_greg20001205_gf/K4greg20001205gf_ch2007Poly.shp")

regions['id'] = regions['name']

# %%
print(regions.columns)
print(regions.head())
# Out:
# Index(['id', 'name', 'geometry'], dtype='object')
#                   id               name  \
# 0   Région lémanique   Région lémanique
# 1  Espace Mittelland  Espace Mittelland
# 2    Nordwestschweiz    Nordwestschweiz
# 3             Zürich             Zürich
# 4         Ostschweiz         Ostschweiz
#
#                                             geometry
# 0  MULTIPOLYGON (((2555415 1138319, 2555536 11384...
# 1  MULTIPOLYGON (((2633238 1223955, 2633643 12219...
# 2  POLYGON ((2611151 1270169, 2611325 1271036, 26...
# 3  POLYGON ((2673825 1238520, 2674860 1239387, 26...
# 4  MULTIPOLYGON (((2716123 1221523, 2715963 12217...

# %%
regions.plot(edgecolor='black', figsize=(8, 8))
plt.title("Grand Regions of Switzerland")
plt.show()

# %%
import folium
import mapclassify
print(gdf)
m = gdf.explore('id')
type(m)
m.save('map.html')
# Out:
#    id               name                                           geometry
# 0   1   Région lémanique  MULTIPOLYGON (((2555415 1138319, 2555536 11384...
# 1   2  Espace Mittelland  MULTIPOLYGON (((2633238 1223955, 2633643 12219...
# 2   3    Nordwestschweiz  POLYGON ((2611151 1270169, 2611325 1271036, 26...
# 3   4             Zürich  POLYGON ((2673825 1238520, 2674860 1239387, 26...
# 4   5         Ostschweiz  MULTIPOLYGON (((2716123 1221523, 2715963 12217...
# 5   6     Zentralschweiz  POLYGON ((2633862 1195150, 2632645 1196055, 26...
# 6   7             Ticino  MULTIPOLYGON (((2727355 1119218, 2729698 11179...
